# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %% [markdown]
# # Top 100 Melodic House & Techno from Beatport

# %%
url = "https://www.beatport.com/genre/melodic-house-techno/90/top-100"

# %%
response = requests.get(url)
response.status_code # 200 status code means OK!
# Out:
# 200

# %%
soup = BeautifulSoup(response.content, "html.parser")
soup
# Out:
# <!DOCTYPE html>
#
# <html>
# <head>
# <meta charset="utf-8"/>
# ...

# %%
charts = soup.select("div.bucket.tracks.top-hundred-tracks > ul > li")

# %%
len(charts)
# Out:
# 100

# %%
charts[0].get_text().split('\n')
# Out:
# ['',
#  '',
#  '',
#  '',
#  '1',
#  '',
#  '',
#  '',
#  'Lose Your Head',
#  'CamelPhat Extended Remix',
#  '',
#  '',
#  '',
#  'London Grammar',
#  '',
#  '',
#  'CamelPhat',
#  '',
#  '',
#  'Ministry of Sound Recordings',
#  '',
#  'Melodic House & Techno',
#  '',
#  '2021-01-22',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '€1.29',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '']

# %%
title = []
version = []
artist = []
label = []
genre = []

# %%
for i in range(len(charts)):
    title.append(soup.select("div.bucket.tracks.top-hundred-tracks > ul > li")[i].get_text().split('\n')[8])
    version.append(soup.select("div.bucket.tracks.top-hundred-tracks > ul > li")[i].get_text().split('\n')[9])
    artist.append(soup.select("div.bucket.tracks.top-hundred-tracks > ul > li")[i].get_text().split('\n')[13])
    label.append(soup.select("div.bucket.tracks.top-hundred-tracks > ul > li")[i].get_text().split('\n')[19])
    genre.append(soup.select("div.bucket.tracks.top-hundred-tracks > ul > li")[i].get_text().split('\n')[21])

# %%
soup.select("div.bucket.tracks.top-hundred-tracks > ul > li")[0].get_text().split('\n')[21]
# Out:
# 'Melodic House & Techno'

# %%
charts_df = pd.DataFrame({'rank':rank, 'artist':artist, 'title':title, 'version':version}, index = rank)

# %%
charts_df
# Out:
#      rank          artist                                   title  \
# 1       1  London Grammar                          Lose Your Head
# 2       2    Ben Bohmer,                                 Run Away
# 3       3    Franky Wah,   Should Have Seen It Coming feat. AETHO
# 4       4        ARTBAT,                                   Fading
# 5       5           Frost                               Overtones
# ..    ...             ...                                     ...
# 96     96    Jean Vayat,                                Your Rain
# 97     97    Trentemoller                                    Moan
# 98     98           Yotto                                Observer
# 99     99           ZHU,                                   Desire
# 100   100        Rhodes,                            For a Feeling
#
#                       version
# 1    CamelPhat Extended Remix
# 2                Extended Mix
# 3                Extended Mix
# 4                Original Mix
# ...

# %% [markdown]
# # Find FBI's most wanted

# %%
url = "https://www.fbi.gov/wanted/topten"

# %%
response = requests.get(url)
response.status_code # 200 status code means OK!
# Out:
# 200

# %%
soup = BeautifulSoup(response.content, "html.parser")
soup
# Out:
# <!DOCTYPE html>
#
# <html data-gridsystem="bs3" lang="en">
# <head>
# <meta charset="utf-8"/>
# <meta content="ie=edge" http-equiv="x-ua-compatible"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <link href="https://www.fbi.gov/wanted/topten" rel="canonical"/><meta content="summary_large_image" name="twitter:card"/>
# <meta content="Ten Most Wanted Fugitives | Federal Bureau of Investigation" name="twitter:title"/>
# <meta content="Federal Bureau of Investigation" property="og:site_name"/>
# <meta content="Ten Most Wanted Fugitives | Federal Bureau of Investigation" property="og:title"/>
# <meta content="website" property="og:type"/>
# <meta content="@FBI" name="twitter:site"/>
# <meta content="https://www.facebook.com/FBI" property="og:article:publisher"/>
# ...

# %%
#query-results-0f737222c5054a81a120bce207b0446a > ul > li:nth-child(1) > a

# %%
links = soup.select('.query-results.pat-pager > ul > li > a')

# %%
len(links)
# Out:
# 10

# %%
urls = []

for link in range(len(links)):
    urls.append(links[link]['href'])

# %%
links[0]['href']
# Out:
# 'https://www.fbi.gov/wanted/topten/rafael-caro-quintero'
